# %% [markdown]
# # DATASET OVERVIEW

# %%
# Loading the required liabries.
import pandas as pd

# %%
# Read the dataset.
car=pd.read_excel('C:\\Users\\abc\\Desktop\\Cars Data.xlsx')
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Top 5 recors of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Number of rows and columns.
car.shape
# Out:
# (432, 15)

# %%
# Names of all the columns.
car.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
# Names of all the columns.
for i in car.columns:
    print(i)
# Out:
# Make
# Model
# Type
# Origin
# DriveTrain
# MSRP
# Invoice
# EngineSize
# Cylinders
# Horsepower
# MPG_City
# MPG_Highway
# Weight
# Wheelbase
# Length

# %%
# Basic stats about the dataset.
car.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %% [markdown]
# # DATA CLEANING

# %%
# Null values in all the columns of the dataset.
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
# Dataset where Cyclinders column has null values.
car[car['Cylinders'].isnull()]
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 30     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 39     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 161    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 173    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 30          NaN        NaN         NaN       NaN          NaN     NaN
# 39          NaN        NaN         NaN       NaN          NaN     NaN
# 161         NaN        NaN         NaN       NaN          NaN     NaN
# 173         NaN        NaN         NaN       NaN          NaN     NaN
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# ...

# %%
# Dropping the rows(30th,39th,161th,173th)
car.drop([30,39,161,173],axis=0,inplace=True)

# %%
# Dataset where Cylinders column has null values. 
car[car['Cylinders'].isnull()]
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# 252         1.3        NaN       238.0      18.0         24.0  3029.0
#
#      Wheelbase  Length
# 251      106.0   174.0
# 252      106.0   174.0

# %%
# Top 5 records of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Mean of the Cylinders column of the dataset.
car['Cylinders'].mean()
# Out:
# 5.807511737089202

# %%
# Replace all the null values in the column Cylinders with the mean of the column Cylinders of the dataset.
car['Cylinders'].fillna(car['Cylinders'].mean(),inplace=True)

# %%
# Null values in all the columns of the dataset.
car.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
# Datatypes of all the columns of the dataset.
car.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %% [markdown]
# # Which company manufactured the most number of vehicles ?

# %%
# Head of the dataset.
car.head(5)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Count of the Make column.
car['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
# Loading the required liabries.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bar-plot of top 5 company who manufactured most number of vehicle.
plt.figure(figsize=(10,5))
sns.barplot(x=list(car['Make'].value_counts()[0:5].keys()),y=list(car['Make'].value_counts()[0:5]),ec='black',lw=1)
plt.xlabel("Name of the Company",fontsize=10)
plt.ylabel("Number of Vehicle",fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that, most of the vehicles are manufactured by Toyota.

# %% [markdown]
# # Which country or continent manufactured the most number of vehicles ?

# %%
# Head of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Count of the Origin column.
car['Origin'].value_counts()
# Out:
# Asia      158
# USA       147
# Europe    123
# Name: Origin, dtype: int64

# %%
# Bar-plot of coutries/continents who manufactured most number of vehicles.
plt.figure(figsize=(10,5))
sns.barplot(x=list(car['Origin'].value_counts()[0:5].keys()),y=list(car['Origin'].value_counts()[0:5]),ec='black',lw=1)
plt.xlabel("Name of the Country/Continent",fontsize=10)
plt.ylabel("Number of Vehicles",fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that, Asia manufactured the most number of Cars.

# %% [markdown]
# # Which is the most longest vehicle ?

# %%
# Top 5 records of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Sort the car dataset in descending order of the Lenght column.
car.sort_values(by=['Length'], ascending=False)
# Out:
#           Make                            Model    Type  Origin DriveTrain  \
# 89   Chevrolet                     Silverado SS   Truck     USA        All
# 148        GMC         Sierra Extended Cab 1500   Truck     USA       Rear
# 120       Ford                Excursion 6.8 XLT     SUV     USA        All
# 318     Nissan                Titan King Cab XE   Truck    Asia        All
# 149        GMC                   Sierra HD 2500   Truck     USA        All
# ..         ...                              ...     ...     ...        ...
# 70   Chevrolet                Aveo LS 4dr hatch   Sedan     USA      Front
# 400     Toyota       MR2 Spyder convertible 2dr  Sports    Asia       Rear
# 207       Jeep  Wrangler Sahara convertible 2dr     SUV     USA        All
# 243       MINI                         Cooper S   Sedan  Europe      Front
# 242       MINI                           Cooper   Sedan  Europe      Front
#
# ...

# %%
# Create a datatset a.
a=car.sort_values(by=['Length'], ascending=False).head()
a
# Out:
#           Make                     Model   Type Origin DriveTrain      MSRP  \
# 89   Chevrolet              Silverado SS  Truck    USA        All  $40,340
# 148        GMC  Sierra Extended Cab 1500  Truck    USA       Rear  $25,717
# 120       Ford         Excursion 6.8 XLT    SUV    USA        All  $41,475
# 318     Nissan         Titan King Cab XE  Truck   Asia        All  $26,650
# 149        GMC            Sierra HD 2500  Truck    USA        All  $29,322
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 89   $35,399          6.0        8.0       300.0      13.0         17.0
# 148  $22,604          4.8        8.0       285.0      17.0         20.0
# 120  $36,494          6.8       10.0       310.0      10.0         13.0
# 318  $24,926          5.6        8.0       305.0      14.0         18.0
# 149  $25,759          6.0        8.0       300.0      13.0         18.0
#
#      Weight  Wheelbase  Length
# 89   4804.0      144.0   238.0
# ...

# %%
# Extract only Model and Length column from the datatset.
a=a[['Model','Length']]
a
# Out:
#                         Model  Length
# 89               Silverado SS   238.0
# 148  Sierra Extended Cab 1500   230.0
# 120         Excursion 6.8 XLT   227.0
# 318         Titan King Cab XE   224.0
# 149            Sierra HD 2500   222.0

# %%
# List of the names of vehicles.
list(a['Model'])
# Out:
# ['Silverado SS',
#  'Sierra Extended Cab 1500',
#  'Excursion 6.8 XLT',
#  'Titan King Cab XE',
#  'Sierra HD 2500']

# %%
# List of the length of the vehicle. 
list(a['Length'])
# Out:
# [238.0, 230.0, 227.0, 224.0, 222.0]

# %%
# Bar-plot of top 5 longest vehicle.
plt.figure(figsize=(13,5))
color = ['black','red','green','orange','blue','limegreen','darkgreen','royalblue','navy']
sns.barplot(x=list(a['Model']),y=list(a['Length']),ec='black',lw=1, palette=color)
plt.xlabel("Name of the Vehicle",fontsize=12)
plt.ylabel("Length of Vehicle",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that, Silverado SSn is the longest vehicle.

# %% [markdown]
# # Which vehicle has highest Horsepower ?

# %%
# Head of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Sort the dataset in the descending order of the Horsepower column. 
car.sort_values(by=['Horsepower'],ascending=False)
# Out:
#               Make                                   Model    Type  Origin  \
# 116          Dodge            Viper SRT-10 convertible 2dr  Sports     USA
# 266  Mercedes-Benz                               CL600 2dr   Sedan  Europe
# 275  Mercedes-Benz                   SL600 convertible 2dr  Sports  Europe
# 274  Mercedes-Benz                            SL55 AMG 2dr  Sports  Europe
# 338        Porsche                             911 GT2 2dr  Sports  Europe
# ..             ...                                     ...     ...     ...
# 174        Hyundai                     Accent GT 2dr hatch   Sedan    Asia
# 69       Chevrolet                                Aveo 4dr   Sedan     USA
# 408     Volkswagen                       Jetta GLS TDI 4dr   Sedan  Europe
# 151          Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid    Asia
# 152          Honda              Insight 2dr (gas/electric)  Hybrid    Asia
#
# ...

# %%
# Create a dataset a.
a=car.sort_values(by=['Horsepower'],ascending=False).head()
a
# Out:
#               Make                         Model    Type  Origin DriveTrain  \
# 116          Dodge  Viper SRT-10 convertible 2dr  Sports     USA       Rear
# 266  Mercedes-Benz                     CL600 2dr   Sedan  Europe       Rear
# 275  Mercedes-Benz         SL600 convertible 2dr  Sports  Europe       Rear
# 274  Mercedes-Benz                  SL55 AMG 2dr  Sports  Europe       Rear
# 338        Porsche                   911 GT2 2dr  Sports  Europe       Rear
#
#           MSRP    Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 116   $81,795    $74,451          8.3       10.0       500.0      12.0
# 266  $128,420   $119,600          5.5       12.0       493.0      13.0
# 275  $126,670   $117,854          5.5       12.0       493.0      13.0
# 274  $121,770   $113,388          5.5        8.0       493.0      14.0
# 338  $192,465   $173,560          3.6        6.0       477.0      17.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
# Extract only Model and Horsepower column from the datatset.
a=a[['Model','Horsepower']]
a
# Out:
#                             Model  Horsepower
# 116  Viper SRT-10 convertible 2dr       500.0
# 266                     CL600 2dr       493.0
# 275         SL600 convertible 2dr       493.0
# 274                  SL55 AMG 2dr       493.0
# 338                   911 GT2 2dr       477.0

# %%
# List of the names of vehicles.
list(a['Model'])
# Out:
# ['Viper SRT-10 convertible 2dr',
#  'CL600 2dr',
#  'SL600 convertible 2dr',
#  'SL55 AMG 2dr',
#  '911 GT2 2dr']

# %%
# List of the Horsepower of the vehicle. 
list(a['Horsepower'])
# Out:
# [500.0, 493.0, 493.0, 493.0, 477.0]

# %%
# Bar-plot of top 5 Horsepower vehicle.
plt.figure(figsize=(13,5))
color = ['purple','orange','pink','red','green','limegreen','darkgreen','royalblue','navy']
sns.barplot(x=list(a['Model']),y=list(a['Horsepower']),ec='black',lw=1, palette=color)
plt.xlabel("Name of the Vehicle",fontsize=12)
plt.ylabel("Count of the Horsepower",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that, Visper SRT-10 convertible 2dr has the highest Horsepower.

# %% [markdown]
# # Which vehicle has most number of cylinders ?

# %%
# Head of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Sort the dataset in the descending order of the Cylinders column. 
car.sort_values(by=['Cylinders'],ascending=False)
# Out:
#               Make                         Model    Type  Origin DriveTrain  \
# 416     Volkswagen               Phaeton W12 4dr   Sedan  Europe      Front
# 266  Mercedes-Benz                     CL600 2dr   Sedan  Europe       Rear
# 275  Mercedes-Benz         SL600 convertible 2dr  Sports  Europe       Rear
# 120           Ford             Excursion 6.8 XLT     SUV     USA        All
# 116          Dodge  Viper SRT-10 convertible 2dr  Sports     USA       Rear
# ..             ...                           ...     ...     ...        ...
# 171        Hyundai              Accent 2dr hatch   Sedan    Asia      Front
# 333        Pontiac                          Vibe   Wagon     USA       Rear
# 172        Hyundai                 Accent GL 4dr   Sedan    Asia      Front
# 218            Kia                     Rio Cinco   Wagon    Asia      Front
# 152          Honda    Insight 2dr (gas/electric)  Hybrid    Asia      Front
#
# ...

# %%
# Create a dataset a.
a=car.sort_values(by=['Cylinders'],ascending=False).head()
a
# Out:
#               Make                         Model    Type  Origin DriveTrain  \
# 416     Volkswagen               Phaeton W12 4dr   Sedan  Europe      Front
# 266  Mercedes-Benz                     CL600 2dr   Sedan  Europe       Rear
# 275  Mercedes-Benz         SL600 convertible 2dr  Sports  Europe       Rear
# 120           Ford             Excursion 6.8 XLT     SUV     USA        All
# 116          Dodge  Viper SRT-10 convertible 2dr  Sports     USA       Rear
#
#           MSRP    Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 416   $75,000    $69,130          6.0       12.0       420.0      12.0
# 266  $128,420   $119,600          5.5       12.0       493.0      13.0
# 275  $126,670   $117,854          5.5       12.0       493.0      13.0
# 120   $41,475    $36,494          6.8       10.0       310.0      10.0
# 116   $81,795    $74,451          8.3       10.0       500.0      12.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
# Extract only Model and Cylinders column from the datatset.
a=a[['Model','Cylinders']]
a
# Out:
#                             Model  Cylinders
# 416               Phaeton W12 4dr       12.0
# 266                     CL600 2dr       12.0
# 275         SL600 convertible 2dr       12.0
# 120             Excursion 6.8 XLT       10.0
# 116  Viper SRT-10 convertible 2dr       10.0

# %%
# List of the names of vehicles.
list(a['Model'])
# Out:
# ['Phaeton W12 4dr',
#  'CL600 2dr',
#  'SL600 convertible 2dr',
#  'Excursion 6.8 XLT',
#  'Viper SRT-10 convertible 2dr']

# %%
# List of the Horsepower of the vehicle. 
list(a['Cylinders'])
# Out:
# [12.0, 12.0, 12.0, 10.0, 10.0]

# %%
# Bar-plot of top 5 Cylinders's vehicle.
plt.figure(figsize=(13,5))
color = ['purple','orange','pink','red','green','limegreen','darkgreen','royalblue','navy']
sns.barplot(x=list(a['Model']),y=list(a['Cylinders']),ec='black',lw=1, palette=color)
plt.xlabel("Name of the Vehicle",fontsize=12)
plt.ylabel("Number of the Cylinders",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that Phaeton W12 4dr, CL600 2dr, SL600 convertible 2dr have the most number of cylinders.

# %% [markdown]
# # Which vehicle has the highest weight ?

# %%
# Head of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Sort the dataset in the descending order of the Weight column. 
car.sort_values(by=['Weight'],ascending=False)
# Out:
#          Make                       Model    Type Origin DriveTrain      MSRP  \
# 120      Ford           Excursion 6.8 XLT     SUV    USA        All  $41,475
# 169    Hummer                          H2     SUV    USA        All  $49,995
# 145       GMC           Yukon XL 2500 SLT     SUV    USA        All  $46,265
# 233   Lincoln            Navigator Luxury     SUV    USA        All  $52,775
# 64   Cadillac                Escalade EXT   Truck    USA        All  $52,975
# ..        ...                         ...     ...    ...        ...       ...
# 400    Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 387    Toyota               Echo 2dr auto   Sedan   Asia      Front  $11,560
# 388    Toyota                    Echo 4dr   Sedan   Asia      Front  $11,290
# 386    Toyota             Echo 2dr manual   Sedan   Asia      Front  $10,760
# 152     Honda  Insight 2dr (gas/electric)  Hybrid   Asia      Front  $19,110
#
# ...

# %%
# Create a dataset a.
a=car.sort_values(by=['Weight'],ascending=False).head()
a
# Out:
#          Make              Model   Type Origin DriveTrain      MSRP   Invoice  \
# 120      Ford  Excursion 6.8 XLT    SUV    USA        All  $41,475   $36,494
# 169    Hummer                 H2    SUV    USA        All  $49,995   $45,815
# 145       GMC  Yukon XL 2500 SLT    SUV    USA        All  $46,265   $40,534
# 233   Lincoln   Navigator Luxury    SUV    USA        All  $52,775   $46,360
# 64   Cadillac       Escalade EXT  Truck    USA        All  $52,975   $48,541
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 120         6.8       10.0       310.0      10.0         13.0  7190.0
# 169         6.0        8.0       316.0      10.0         12.0  6400.0
# 145         6.0        8.0       325.0      13.0         17.0  6133.0
# 233         5.4        8.0       300.0      13.0         18.0  5969.0
# 64          6.0        8.0       345.0      13.0         17.0  5879.0
#
#      Wheelbase  Length
# 120      137.0   227.0
# 169      123.0   190.0
# ...

# %%
# Extract only Model and Weight column from the datatset.
a=a[['Model','Weight']]
a
# Out:
#                  Model  Weight
# 120  Excursion 6.8 XLT  7190.0
# 169                 H2  6400.0
# 145  Yukon XL 2500 SLT  6133.0
# 233   Navigator Luxury  5969.0
# 64        Escalade EXT  5879.0

# %%
# List of the names of vehicles.
list(a['Model'])
# Out:
# ['Excursion 6.8 XLT',
#  'H2',
#  'Yukon XL 2500 SLT',
#  'Navigator Luxury',
#  'Escalade EXT']

# %%
# List of the Weight of the vehicle. 
list(a['Weight'])
# Out:
# [7190.0, 6400.0, 6133.0, 5969.0, 5879.0]

# %%
# Bar-plot of top 5 vehicle with highest weight.
plt.figure(figsize=(13,5))
color = ['purple','orange','pink','red','green','limegreen','darkgreen','royalblue','navy']
sns.barplot(x=list(a['Model']),y=list(a['Weight']),ec='black',lw=1, palette=color)
plt.xlabel("Name of the Vehicle",fontsize=12)
plt.ylabel("Weight of Vehicle",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that, Excursion 6.8 XLT has the highest weight.

# %% [markdown]
# # Which vehicle has the highest MSRP ?

# %%
# Head of the dataset.
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Sort the dataset in the descending order of the MSRP column. 
car.sort_values(by=['MSRP'],ascending=False)
# Out:
#               Make                   Model    Type  Origin DriveTrain  \
# 265  Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear
# 273  Mercedes-Benz   SL500 convertible 2dr  Sports  Europe       Rear
# 6            Acura  NSX coupe 2dr manual S  Sports    Asia       Rear
# 204         Jaguar     XKR convertible 2dr  Sports  Europe       Rear
# 272  Mercedes-Benz                S500 4dr   Sedan  Europe        All
# ..             ...                     ...     ...     ...        ...
# 211            Kia            Rio 4dr auto   Sedan    Asia      Front
# 349         Saturn                Ion1 4dr   Sedan     USA      Front
# 386         Toyota         Echo 2dr manual   Sedan    Asia      Front
# 171        Hyundai        Accent 2dr hatch   Sedan    Asia      Front
# 210            Kia          Rio 4dr manual   Sedan    Asia      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# ...

# %%
# Create a dataset a.
a=car.sort_values(by=['MSRP'],ascending=False).head()
a
# Out:
#               Make                   Model    Type  Origin DriveTrain  \
# 265  Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear
# 273  Mercedes-Benz   SL500 convertible 2dr  Sports  Europe       Rear
# 6            Acura  NSX coupe 2dr manual S  Sports    Asia       Rear
# 204         Jaguar     XKR convertible 2dr  Sports  Europe       Rear
# 272  Mercedes-Benz                S500 4dr   Sedan  Europe        All
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 265  $94,820   $88,324          5.0        8.0       302.0      16.0
# 273  $90,520   $84,325          5.0        8.0       302.0      16.0
# 6    $89,765   $79,978          3.2        6.0       290.0      17.0
# 204  $86,995   $79,226          4.2        8.0       390.0      16.0
# 272  $86,970   $80,939          5.0        8.0       302.0      16.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# 265         24.0  4085.0      114.0   196.0
# ...

# %%
# Extract only Model and MSRP column from the datatset.
a=a[['Model','MSRP']]
a
# Out:
#                       Model      MSRP
# 265               CL500 2dr  $94,820
# 273   SL500 convertible 2dr  $90,520
# 6    NSX coupe 2dr manual S  $89,765
# 204     XKR convertible 2dr  $86,995
# 272                S500 4dr  $86,970

# %%
# List of the names of vehicles.
list(a['Model'])
# Out:
# ['CL500 2dr',
#  'SL500 convertible 2dr',
#  'NSX coupe 2dr manual S',
#  'XKR convertible 2dr',
#  'S500 4dr']

# %%
# List of the MSRP of the vehicle. 
list(a['MSRP'])
# Out:
# ['$94,820 ', '$90,520 ', '$89,765 ', '$86,995 ', '$86,970 ']

# %% [markdown]
# From the above we can say that, CL500 2dr has the highest MSRP
